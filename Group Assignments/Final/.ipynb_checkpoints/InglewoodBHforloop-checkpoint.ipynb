# %% [markdown]
# ## CalEnviroScreen
# This notebook cleans up CalEnviroscreen data and then zooms into two focus areas: Inglewood and Beverly Hills.

# %% [markdown]
# # Setting up the data

# %% [markdown]
# Started by importing pandas and geopandas.

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# I then ask pandas to read the file and converted a few of the location variables to strings in order to allow for some of the sorting and to zfill the information.

# %%
df = pd.read_csv('Data/Calenviroscreen4.csv',
    dtype=
    {
        'Census Tract':str,
        'California County':str,
        'Approximate Location': str
    }
)
df.head()
# Out:
#   Census Tract  Total Population California County    ZIP  \
# 0   6019001100              2780           Fresno   93706
# 1   6077000700              4680       San Joaquin  95206
# 2   6037204920              2751       Los Angeles  90023
# 3   6019000700              3664           Fresno   93706
# 4   6019000200              2689           Fresno   93706
#
#   Approximate Location   Longitude   Latitude  CES 4.0 Score  \
# 0               Fresno -119.781696  36.709695          93.18
# 1             Stockton -121.287873  37.943173          86.65
# 2          Los Angeles -118.197497  34.017500          82.39
# 3               Fresno -119.827707  36.734535          81.33
# 4               Fresno -119.805504  36.735491          80.75
#
#    CES 4.0 Percentile  CES 4.0 Percentile Range  ...  \
# 0              100.00  95-100% (highest scores)  ...
# 1               99.99  95-100% (highest scores)  ...
# 2               99.97  95-100% (highest scores)  ...
# 3               99.96  95-100% (highest scores)  ...
# 4               99.95  95-100% (highest scores)  ...
#
#    Linguistic Isolation Pctl  Poverty  Poverty Pctl  Unemployment  \
# 0                      79.37     76.0         98.92          12.8
# 1                      95.53     73.2         98.39          19.8
# 2                      81.55     62.6         93.39           6.4
# 3                      78.71     65.7         95.35          15.7
# 4                      86.56     72.7         98.30          13.7
#
#    Unemployment Pctl  Housing Burden  Housing Burden Pctl  Pop. Char.   \
# 0              93.83            30.3                91.04        93.16
# 1              99.21            31.2                92.28        93.17
# 2              61.53            20.3                63.97        83.75
# 3              97.35            35.4                96.41        94.64
# 4              95.29            32.7                94.16        95.40
#
#    Pop. Char. Score  Pop. Char. Pctl
# 0              9.66            99.72
# 1              9.66            99.74
# 2              8.69            95.79
# 3              9.82            99.89
# 4              9.90            99.95
#
# [5 rows x 58 columns]

# %% [markdown]
# Above, we see that the leading zero is missing from the data, so I zfilled the information.

# %%
df['Census Tract'] = df['Census Tract'].str.zfill(11)

# %%
# look at the data types, verbose = True shows us all the counts
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8035 entries, 0 to 8034
# Data columns (total 58 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Census Tract                 8035 non-null   object
#  1   Total Population             8035 non-null   int64
#  2   California County            8035 non-null   object
#  3   ZIP                          8035 non-null   int64
#  4   Approximate Location         8035 non-null   object
#  5   Longitude                    8035 non-null   float64
#  6   Latitude                     8035 non-null   float64
#  7   CES 4.0 Score                7932 non-null   float64
#  8   CES 4.0 Percentile           7932 non-null   float64
#  9   CES 4.0 Percentile Range     7932 non-null   object
#  10  Ozone                        8035 non-null   float64
#  11  Ozone Pctl                   8035 non-null   float64
#  12  PM2.5                        8035 non-null   float64
#  13  PM2.5 Pctl                   8035 non-null   float64
#  14  Diesel PM                    8035 non-null   float64
#  15  Diesel PM Pctl               8035 non-null   float64
#  16  Drinking Water               8007 non-null   float64
#  17  Drinking Water Pctl          8007 non-null   float64
#  18  Lead                         7939 non-null   float64
#  19  Lead Pctl                    7939 non-null   float64
#  20  Pesticides                   8035 non-null   float64
#  21  Pesticides Pctl              8035 non-null   float64
#  22  Tox. Release                 8035 non-null   float64
#  23  Tox. Release Pctl            8035 non-null   float64
#  24  Traffic                      8000 non-null   float64
#  25  Traffic Pctl                 8000 non-null   float64
#  26  Cleanup Sites                8035 non-null   float64
#  27  Cleanup Sites Pctl           8035 non-null   float64
#  28  Groundwater Threats          8035 non-null   float64
#  29  Groundwater Threats Pctl     8035 non-null   float64
#  30  Haz. Waste                   8035 non-null   float64
#  31  Haz. Waste Pctl              8035 non-null   float64
#  32  Imp. Water Bodies            8035 non-null   int64
#  33  Imp. Water Bodies Pctl       8035 non-null   float64
#  34  Solid Waste                  8035 non-null   float64
#  35  Solid Waste Pctl             8035 non-null   float64
#  36  Pollution Burden             8035 non-null   float64
#  37  Pollution Burden Score       8035 non-null   float64
#  38  Pollution Burden Pctl        8035 non-null   float64
#  39  Asthma                       8024 non-null   float64
#  40  Asthma Pctl                  8024 non-null   float64
#  41  Low Birth Weight             7808 non-null   float64
#  42  Low Birth Weight Pctl        7808 non-null   float64
#  43  Cardiovascular Disease       8024 non-null   float64
#  44  Cardiovascular Disease Pctl  8024 non-null   float64
#  45  Education                    7932 non-null   float64
#  46  Education Pctl               7932 non-null   float64
#  47  Linguistic Isolation         7715 non-null   float64
#  48  Linguistic Isolation Pctl    7715 non-null   float64
#  49  Poverty                      7960 non-null   float64
#  50  Poverty Pctl                 7960 non-null   float64
#  51  Unemployment                 7700 non-null   float64
#  52  Unemployment Pctl            7700 non-null   float64
#  53  Housing Burden               7890 non-null   float64
#  54  Housing Burden Pctl          7890 non-null   float64
#  55  Pop. Char.                   7932 non-null   float64
#  56  Pop. Char. Score             7932 non-null   float64
#  57  Pop. Char. Pctl              7932 non-null   float64
# dtypes: float64(51), int64(3), object(4)
# memory usage: 3.6+ MB

# %% [markdown]
# I then filtered to columns I was interested in examining further in this assignment.

# %%
columns_to_keep = ['Census Tract',
                   'Total Population',
                   'California County',
                   'Approximate Location',
                   'CES 4.0 Score',
                   'CES 4.0 Percentile',
                   'CES 4.0 Percentile Range',
                   'PM2.5 Pctl',
                   'Groundwater Threats Pctl',
                   'Asthma Pctl',
                   'Low Birth Weight Pctl',
                   'Unemployment Pctl',
                   'Housing Burden Pctl']
df2 = df[columns_to_keep]
df2.info
# Out:
# <bound method DataFrame.info of      Census Tract  Total Population California County  \
# 0     06019001100              2780           Fresno
# 1     06077000700              4680       San Joaquin
# 2     06037204920              2751       Los Angeles
# 3     06019000700              3664           Fresno
# 4     06019000200              2689           Fresno
# ...           ...               ...               ...
# 8030  06107004000               582           Tulare
# 8031  06109985202              2509         Tuolumne
# 8032  06111001206               778          Ventura
# 8033  06111003012               675          Ventura
# 8034  06111980000               118          Ventura
#
#                      Approximate Location  CES 4.0 Score  CES 4.0 Percentile  \
# 0                                  Fresno          93.18              100.00
# 1                                Stockton          86.65               99.99
# 2                             Los Angeles          82.39               99.97
# 3                                  Fresno          81.33               99.96
# 4                                  Fresno          80.75               99.95
# ...                                   ...            ...                 ...
# 8030                          Porterville            NaN                 NaN
# 8031  Unincorporated Tuolumne County area            NaN                 NaN
# 8032   Unincorporated Ventura County area            NaN                 NaN
# 8033                               Oxnard            NaN                 NaN
# 8034   Unincorporated Ventura County area            NaN                 NaN
#
#       CES 4.0 Percentile Range  PM2.5 Pctl  Groundwater Threats Pctl  \
# 0     95-100% (highest scores)       97.71                     91.17
# 1     95-100% (highest scores)       72.59                     95.09
# 2     95-100% (highest scores)       89.21                     68.92
# 3     95-100% (highest scores)       95.88                     44.83
# 4     95-100% (highest scores)       97.47                     78.05
# ...                        ...         ...                       ...
# 8030                       NaN       94.49                      0.00
# 8031                       NaN       40.96                     22.12
# 8032                       NaN       16.74                     66.96
# 8033                       NaN       36.94                      2.11
# 8034                       NaN        2.87                      0.00
#
#       Asthma Pctl  Low Birth Weight Pctl  Unemployment Pctl  \
# 0           97.22                  95.62              93.83
# 1           94.22                  88.72              99.21
# 2           82.76                  90.89              61.53
# 3           98.24                  99.78              97.35
# 4           98.17                  99.67              95.29
# ...           ...                    ...                ...
# 8030        71.09                    NaN                NaN
# 8031        77.57                    NaN                NaN
# 8032        54.06                    NaN                NaN
# 8033        49.25                    NaN                NaN
# 8034        71.88                    NaN                NaN
#
#       Housing Burden Pctl
# 0                   91.04
# 1                   92.28
# 2                   63.97
# 3                   96.41
# 4                   94.16
# ...                   ...
# 8030                  NaN
# 8031                  NaN
# 8032                78.47
# 8033                  NaN
# 8034                  NaN
#
# [8035 rows x 13 columns]>

# %% [markdown]
# Next, I narrow this information to the county of Los Angeles.

# %%
df2LA = df2[df2['California County'] == 'Los Angeles']

# %%
df2LA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2343 entries, 2 to 7990
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Census Tract              2343 non-null   object
#  1   Total Population          2343 non-null   int64
#  2   California County         2343 non-null   object
#  3   Approximate Location      2343 non-null   object
#  4   CES 4.0 Score             2297 non-null   float64
#  5   CES 4.0 Percentile        2297 non-null   float64
#  6   CES 4.0 Percentile Range  2297 non-null   object
#  7   PM2.5 Pctl                2343 non-null   float64
#  8   Groundwater Threats Pctl  2343 non-null   float64
#  9   Asthma Pctl               2334 non-null   float64
#  10  Low Birth Weight Pctl     2279 non-null   float64
#  11  Unemployment Pctl         2263 non-null   float64
#  12  Housing Burden Pctl       2283 non-null   float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 256.3+ KB

# %% [markdown]
# I then connected this data to geography information that we had been provided in class. This takes a couple of steps.

# %%
#first asking gpd to read the census information and seeing the first five rows to see how to connect the information.
tracts = gpd.read_file('Data/2020_Census_Tracts.geojson')
tracts.head()
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed
#    OBJECTID    CT20    LABEL   ShapeSTArea  ShapeSTLength  \
# 0      4992  101110  1011.10  1.229562e+07   15083.854287
# 1      4993  101122  1011.22  2.845774e+07   31671.455844
# 2      4994  101220  1012.20  7.522093e+06   12698.783810
# 3      4995  101221  1012.21  3.812000e+06    9161.710543
# 4      4996  101222  1012.22  3.191371e+06    9980.600461
#
#                                             geometry
# 0  POLYGON ((-118.29793 34.26323, -118.30082 34.2...
# 1  POLYGON ((-118.27743 34.25991, -118.27743 34.2...
# 2  POLYGON ((-118.27818 34.25577, -118.27887 34.2...
# 3  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  POLYGON ((-118.28594 34.25590, -118.28697 34.2...

# %%
#next I used created a column to match the data in CalEnviroscreen
tracts['Census Tract'] ='06' + '037' + tracts['CT20']

# %%
#And then merged the two datasets
CEStracts=tracts.merge(df2,on="Census Tract")

# %% [markdown]
# After this, I also confirm that the projection of the geodataframe is mercator in order to allow us to join our calenviroscreen information with information about oil wells in the county.

# %%
CEStracts.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# # Oil Wells Data + Inglewood

# %% [markdown]
# As we are looking at oil wells data, I added oil wells to the calenviroscreen information, although this doesn't necessarily work out very well. I also removed the filter on active oil wells as this only showed 3 non-null figures once I zoomed into Inglewood.

# %%
dfoil = pd.read_csv('Data/Oil_Wells.csv')

# %% [markdown]
# I converted this into a geodataframe in the mercator projection to pair with CalEnviroscreen

# %%
gdf_oil = gpd.GeoDataFrame(dfoil, 
                       crs='epsg:4326',
                       geometry=gpd.points_from_xy(dfoil.Longitude, dfoil.Latitude))

# %% [markdown]
# I then performed a spatial join, on the right to use the geometry from the cal enviroscreen dataset and to include oil wells located within a census tract.

# %%
# Perform a spatial join based on geographic coordinates
gdfoilCES = gpd.sjoin(gdf_oil, CEStracts, how='right', op='within')
gdfoilCES.head()
# Out:
# /opt/conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3493: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#    index_left   X   Y  OBJECTID_left DistrictNu  APINumber BLMWell DryHole  \
# 0         NaN NaN NaN            NaN        NaN        NaN     NaN     NaN
# 1         NaN NaN NaN            NaN        NaN        NaN     NaN     NaN
# 2         NaN NaN NaN            NaN        NaN        NaN     NaN     NaN
# 3         NaN NaN NaN            NaN        NaN        NaN     NaN     NaN
# 4         NaN NaN NaN            NaN        NaN        NaN     NaN     NaN
#
#   WellStatus OperatorNa  ... Approximate Location CES 4.0 Score  \
# 0        NaN        NaN  ...          Los Angeles         23.81
# 1        NaN        NaN  ...          Los Angeles         13.17
# 2        NaN        NaN  ...          Los Angeles         30.64
# 3        NaN        NaN  ...          Los Angeles         19.86
# 4        NaN        NaN  ...          Los Angeles         27.07
#
#   CES 4.0 Percentile  CES 4.0 Percentile Range PM2.5 Pctl  \
# 0              46.28                    45-50%      57.90
# 1              20.84                    20-25%      55.61
# 2              59.95                    55-60%      57.51
# 3              37.15                    35-40%      55.00
# 4              53.18                    50-55%      56.14
#
#   Groundwater Threats Pctl Asthma Pctl  Low Birth Weight Pctl  \
# 0                     0.00       26.53                  13.91
# 1                     0.00       19.65                  32.47
# 2                     2.11       26.53                  36.14
# 3                    35.66       13.06                  17.68
# 4                    14.93       15.28                  60.06
#
#    Unemployment Pctl Housing Burden Pctl
# 0              69.98               93.89
# 1              49.86               37.48
# 2              86.75               95.25
# 3              35.02               56.86
# 4              58.36               53.12
#
# [5 rows x 46 columns]

# %% [markdown]
# gdfoilCES.info()

# %% [markdown]
# There are some null responses in joining the datasets that we should keep in mind. It will also probably make sense to cut down on the amount of columns here as well, but for right now, I'm going to test out mapping the data.

# %%
gdfIW = gdfoilCES[gdfoilCES['Approximate Location'] == 'Inglewood']

# %%
gdfIW.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 139 entries, 1675 to 1705
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index_left                127 non-null    float64
#  1   X                         127 non-null    float64
#  2   Y                         127 non-null    float64
#  3   OBJECTID_left             127 non-null    float64
#  4   DistrictNu                127 non-null    object
#  5   APINumber                 127 non-null    float64
#  6   BLMWell                   127 non-null    object
#  7   DryHole                   127 non-null    object
#  8   WellStatus                127 non-null    object
#  9   OperatorNa                127 non-null    object
#  10  CountyName                127 non-null    object
#  11  FieldName                 127 non-null    object
#  12  AreaName                  127 non-null    object
#  13  Section                   127 non-null    float64
#  14  Township                  127 non-null    object
#  15  Range                     127 non-null    object
#  16  BaseMeridi                127 non-null    object
#  17  Latitude                  127 non-null    float64
#  18  Longitude                 127 non-null    float64
#  19  GISSourceC                127 non-null    object
#  20  LeaseName                 127 non-null    object
#  21  Directiona                127 non-null    object
#  22  GISSymbol                 127 non-null    object
#  23  LatestUpdate              127 non-null    object
#  24  DataSource                127 non-null    object
#  25  TOOLTIP                   127 non-null    object
#  26  NLA_URL                   127 non-null    object
#  27  OBJECTID_right            139 non-null    int64
#  28  CT20                      139 non-null    object
#  29  LABEL                     139 non-null    object
#  30  ShapeSTArea               139 non-null    float64
#  31  ShapeSTLength             139 non-null    float64
#  32  geometry                  139 non-null    geometry
#  33  Census Tract              139 non-null    object
#  34  Total Population          139 non-null    int64
#  35  California County         139 non-null    object
#  36  Approximate Location      139 non-null    object
#  37  CES 4.0 Score             139 non-null    float64
#  38  CES 4.0 Percentile        139 non-null    float64
#  39  CES 4.0 Percentile Range  139 non-null    object
#  40  PM2.5 Pctl                139 non-null    float64
#  41  Groundwater Threats Pctl  139 non-null    float64
#  42  Asthma Pctl               139 non-null    float64
#  43  Low Birth Weight Pctl     139 non-null    float64
#  44  Unemployment Pctl         137 non-null    float64
#  45  Housing Burden Pctl       139 non-null    float64
# dtypes: float64(18), geometry(1), int64(2), object(25)
# memory usage: 51.0+ KB

# %% [markdown]
# # Mapping and visuals - Inglewood

# %% [markdown]
# Now to think about visualizations, chart and map options. I am going to focus on the CalEnviroscreen data.

# %%
import plotly.express as px

# %%
import matplotlib.pyplot as plt
import contextily as ctx

# %% [markdown]
# After importing plotly, matplotlib, and contextily, I started with a map of CalEnviroscreen.

# %%
fig,ax = plt.subplots(figsize=(12,12))

gdfIW.plot(ax=ax,column='CES 4.0 Percentile',legend=True,cmap='RdPu')
# Out:
# <Axes: >

# %% [markdown]
# After this, I add the oil wells to the map.

# %%
fig,ax = plt.subplots(figsize=(12,12))

# plot variable
gdfIW.plot(ax=ax,column='CES 4.0 Percentile',legend=True,cmap='RdPu')

# plot oil wells
ax.scatter(gdfIW['Longitude'], gdfIW['Latitude'], color='black', marker='o', label='Oil Wells', s=20)

plt.legend()
plt.savefig('CESoilW.png')
plt.show()

# %% [markdown]
# Next, I created a function that would run through different columns of calenviroscreen to get a sense of how the environmental and health considerations in the dataset were related to that CES score and varies across census tracts in Inglewood.

# %%
def plot_CES_map(gdf, factor, ax, overlay_points=None):

    # Plot CES data
    gdf.plot(ax=ax, column=factor, legend=True, cmap='RdPu')
    ax.set_title(factor)

    # show oil wells as an overlay
    if overlay_points is not None:
        # Plot overlay points
        ax.scatter(overlay_points['Longitude'], overlay_points['Latitude'], color='black', marker='o', label='Oil Wells', s=20)
    
def calenvirofactor():
    fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(18, 18))
    axs = axs.flatten()

    # List of factors
    factors = ['PM2.5 Pctl','Groundwater Threats Pctl', 'Asthma Pctl','Low Birth Weight Pctl','Unemployment Pctl','Housing Burden Pctl']

    for factor, ax in zip(factors, axs):
        plot_CES_map(gdfIW, factor, ax, overlay_points=gdfIW)
  

    plt.tight_layout()
    plt.savefig('IWforloop1.png')
    plt.show()

calenvirofactor()

# %% [markdown]
# Another version without the legends for hopefully lessening the size of the graphic.

# %%
def plot_CES_map(gdf, factor, ax, overlay_points=None):

    # Plot CES data
    gdf.plot(ax=ax, column=factor, legend=False, cmap='RdPu')
    ax.set_title(factor)

    # show oil wells as an overlay
    if overlay_points is not None:
        # Plot overlay points
        ax.scatter(overlay_points['Longitude'], overlay_points['Latitude'], color='black', marker='o', label='Oil Wells', s=20)
    
def calenvirofactor():
    fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(18, 18))
    axs = axs.flatten()

    # List of factors
    factors = ['PM2.5 Pctl','Groundwater Threats Pctl', 'Asthma Pctl','Low Birth Weight Pctl','Unemployment Pctl','Housing Burden Pctl']

    for factor, ax in zip(factors, axs):
        plot_CES_map(gdfIW, factor, ax, overlay_points=gdfIW)
  

    plt.tight_layout()
    plt.savefig('IWforloop2.png')
    plt.show()

calenvirofactor()

# %% [markdown]
# # Oil Wells Data + Beverly Hills

# %%
gdfBH = gdfoilCES[gdfoilCES['Approximate Location'] == 'Beverly Hills']

# %%
gdfIW.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 139 entries, 1675 to 1705
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index_left                127 non-null    float64
#  1   X                         127 non-null    float64
#  2   Y                         127 non-null    float64
#  3   OBJECTID_left             127 non-null    float64
#  4   DistrictNu                127 non-null    object
#  5   APINumber                 127 non-null    float64
#  6   BLMWell                   127 non-null    object
#  7   DryHole                   127 non-null    object
#  8   WellStatus                127 non-null    object
#  9   OperatorNa                127 non-null    object
#  10  CountyName                127 non-null    object
#  11  FieldName                 127 non-null    object
#  12  AreaName                  127 non-null    object
#  13  Section                   127 non-null    float64
#  14  Township                  127 non-null    object
#  15  Range                     127 non-null    object
#  16  BaseMeridi                127 non-null    object
#  17  Latitude                  127 non-null    float64
#  18  Longitude                 127 non-null    float64
#  19  GISSourceC                127 non-null    object
#  20  LeaseName                 127 non-null    object
#  21  Directiona                127 non-null    object
#  22  GISSymbol                 127 non-null    object
#  23  LatestUpdate              127 non-null    object
#  24  DataSource                127 non-null    object
#  25  TOOLTIP                   127 non-null    object
#  26  NLA_URL                   127 non-null    object
#  27  OBJECTID_right            139 non-null    int64
#  28  CT20                      139 non-null    object
#  29  LABEL                     139 non-null    object
#  30  ShapeSTArea               139 non-null    float64
#  31  ShapeSTLength             139 non-null    float64
#  32  geometry                  139 non-null    geometry
#  33  Census Tract              139 non-null    object
#  34  Total Population          139 non-null    int64
#  35  California County         139 non-null    object
#  36  Approximate Location      139 non-null    object
#  37  CES 4.0 Score             139 non-null    float64
#  38  CES 4.0 Percentile        139 non-null    float64
#  39  CES 4.0 Percentile Range  139 non-null    object
#  40  PM2.5 Pctl                139 non-null    float64
#  41  Groundwater Threats Pctl  139 non-null    float64
#  42  Asthma Pctl               139 non-null    float64
#  43  Low Birth Weight Pctl     139 non-null    float64
#  44  Unemployment Pctl         137 non-null    float64
#  45  Housing Burden Pctl       139 non-null    float64
# dtypes: float64(18), geometry(1), int64(2), object(25)
# memory usage: 51.0+ KB

# %% [markdown]
# # Mapping and Visuals - Beverly Hills

# %% [markdown]
# Now to think about visualizations, chart and map options. I am going to focus on the CalEnviroscreen data.

# %%
import plotly.express as px

# %%
import matplotlib.pyplot as plt
import contextily as ctx

# %%
fig,ax = plt.subplots(figsize=(12,12))

gdfBH.plot(ax=ax,column='CES 4.0 Percentile',legend=True,cmap='Greens')
# Out:
# <Axes: >

# %%
fig,ax = plt.subplots(figsize=(12,12))

# plot variable
gdfBH.plot(ax=ax,column='CES 4.0 Percentile',legend=True,cmap='Greens')

# plot oil wells
ax.scatter(gdfBH['Longitude'], gdfBH['Latitude'], color='black', marker='o', label='Oil Wells', s=20)

plt.legend()
plt.savefig('CESoilWBH.png')
plt.show()

# %%
def plot_CES_map2(gdf, factor, ax, overlay_points=None):

    # Plot CES data
    gdf.plot(ax=ax, column=factor, legend=True, cmap='Greens')
    ax.set_title(factor)

    # show oil wells as an overlay
    if overlay_points is not None:
        # Plot overlay points
        ax.scatter(overlay_points['Longitude'], overlay_points['Latitude'], color='black', marker='o', label='Oil Wells', s=20)
    
def calenvirofactor():
    fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(18, 18))
    axs = axs.flatten()

    # List of factors
    factors = ['PM2.5 Pctl','Groundwater Threats Pctl', 'Asthma Pctl','Low Birth Weight Pctl','Unemployment Pctl','Housing Burden Pctl']

    for factor, ax in zip(factors, axs):
        plot_CES_map2(gdfBH, factor, ax, overlay_points=gdfBH)
  

    plt.tight_layout()
    plt.savefig('BHforloop1.png')
    plt.show()

calenvirofactor()

# %%
def plot_CES_map2(gdf, factor, ax, overlay_points=None):

    # Plot CES data
    gdf.plot(ax=ax, column=factor, legend=False, cmap='Greens')
    ax.set_title(factor)

    # show oil wells as an overlay
    if overlay_points is not None:
        # Plot overlay points
        ax.scatter(overlay_points['Longitude'], overlay_points['Latitude'], color='black', marker='o', label='Oil Wells', s=20)
    
def calenvirofactor():
    fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(18, 18))
    axs = axs.flatten()

    # List of factors
    factors = ['PM2.5 Pctl','Groundwater Threats Pctl', 'Asthma Pctl','Low Birth Weight Pctl','Unemployment Pctl','Housing Burden Pctl']

    for factor, ax in zip(factors, axs):
        plot_CES_map2(gdfBH, factor, ax, overlay_points=gdfBH)
  

    plt.tight_layout()
    plt.savefig('BHforloop2.png')
    plt.show()

calenvirofactor()
