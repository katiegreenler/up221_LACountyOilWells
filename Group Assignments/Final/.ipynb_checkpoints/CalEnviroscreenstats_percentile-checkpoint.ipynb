# %% [markdown]
# ## CalEnviroScreen
# Looking again at CalEnviroscreen, this time through the CSV rather than the shapefile data.

# %% [markdown]
# # Setting up the data

# %% [markdown]
# Started by importing pandas and geopandas.

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# I then ask pandas to read the file and converted a few of the location variables to strings in order to allow for some of the sorting and to zfill the information.

# %%
df = pd.read_csv('Data/Calenviroscreen4.csv',
    dtype=
    {
        'Census Tract':str,
        'California County':str,
        'Approximate Location': str
    }
)
df.head()
# Out:
#   Census Tract  Total Population California County    ZIP  \
# 0   6019001100              2780           Fresno   93706
# 1   6077000700              4680       San Joaquin  95206
# 2   6037204920              2751       Los Angeles  90023
# 3   6019000700              3664           Fresno   93706
# 4   6019000200              2689           Fresno   93706
#
#   Approximate Location   Longitude   Latitude  CES 4.0 Score  \
# 0               Fresno -119.781696  36.709695          93.18
# 1             Stockton -121.287873  37.943173          86.65
# 2          Los Angeles -118.197497  34.017500          82.39
# 3               Fresno -119.827707  36.734535          81.33
# 4               Fresno -119.805504  36.735491          80.75
#
#    CES 4.0 Percentile  CES 4.0 Percentile Range  ...  \
# 0              100.00  95-100% (highest scores)  ...
# 1               99.99  95-100% (highest scores)  ...
# 2               99.97  95-100% (highest scores)  ...
# 3               99.96  95-100% (highest scores)  ...
# 4               99.95  95-100% (highest scores)  ...
#
#    Linguistic Isolation Pctl  Poverty  Poverty Pctl  Unemployment  \
# 0                      79.37     76.0         98.92          12.8
# 1                      95.53     73.2         98.39          19.8
# 2                      81.55     62.6         93.39           6.4
# 3                      78.71     65.7         95.35          15.7
# 4                      86.56     72.7         98.30          13.7
#
#    Unemployment Pctl  Housing Burden  Housing Burden Pctl  Pop. Char.   \
# 0              93.83            30.3                91.04        93.16
# 1              99.21            31.2                92.28        93.17
# 2              61.53            20.3                63.97        83.75
# 3              97.35            35.4                96.41        94.64
# 4              95.29            32.7                94.16        95.40
#
#    Pop. Char. Score  Pop. Char. Pctl
# 0              9.66            99.72
# 1              9.66            99.74
# 2              8.69            95.79
# 3              9.82            99.89
# 4              9.90            99.95
#
# [5 rows x 58 columns]

# %% [markdown]
# Above, we see that the leading zero is missing from the data, so I zfilled the information and then simplified the information to location and CalEnviroscreen percentile measures.

# %%
df['Census Tract'] = df['Census Tract'].str.zfill(11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8035 entries, 0 to 8034
# Data columns (total 58 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Census Tract                 8035 non-null   object
#  1   Total Population             8035 non-null   int64
#  2   California County            8035 non-null   object
#  3   ZIP                          8035 non-null   int64
#  4   Approximate Location         8035 non-null   object
#  5   Longitude                    8035 non-null   float64
#  6   Latitude                     8035 non-null   float64
#  7   CES 4.0 Score                7932 non-null   float64
#  8   CES 4.0 Percentile           7932 non-null   float64
#  9   CES 4.0 Percentile Range     7932 non-null   object
#  10  Ozone                        8035 non-null   float64
#  11  Ozone Pctl                   8035 non-null   float64
#  12  PM2.5                        8035 non-null   float64
#  13  PM2.5 Pctl                   8035 non-null   float64
#  14  Diesel PM                    8035 non-null   float64
#  15  Diesel PM Pctl               8035 non-null   float64
#  16  Drinking Water               8007 non-null   float64
#  17  Drinking Water Pctl          8007 non-null   float64
#  18  Lead                         7939 non-null   float64
#  19  Lead Pctl                    7939 non-null   float64
#  20  Pesticides                   8035 non-null   float64
#  21  Pesticides Pctl              8035 non-null   float64
#  22  Tox. Release                 8035 non-null   float64
#  23  Tox. Release Pctl            8035 non-null   float64
#  24  Traffic                      8000 non-null   float64
#  25  Traffic Pctl                 8000 non-null   float64
#  26  Cleanup Sites                8035 non-null   float64
#  27  Cleanup Sites Pctl           8035 non-null   float64
#  28  Groundwater Threats          8035 non-null   float64
#  29  Groundwater Threats Pctl     8035 non-null   float64
#  30  Haz. Waste                   8035 non-null   float64
#  31  Haz. Waste Pctl              8035 non-null   float64
#  32  Imp. Water Bodies            8035 non-null   int64
#  33  Imp. Water Bodies Pctl       8035 non-null   float64
#  34  Solid Waste                  8035 non-null   float64
#  35  Solid Waste Pctl             8035 non-null   float64
#  36  Pollution Burden             8035 non-null   float64
#  37  Pollution Burden Score       8035 non-null   float64
#  38  Pollution Burden Pctl        8035 non-null   float64
#  39  Asthma                       8024 non-null   float64
#  40  Asthma Pctl                  8024 non-null   float64
#  41  Low Birth Weight             7808 non-null   float64
#  42  Low Birth Weight Pctl        7808 non-null   float64
#  43  Cardiovascular Disease       8024 non-null   float64
#  44  Cardiovascular Disease Pctl  8024 non-null   float64
#  45  Education                    7932 non-null   float64
#  46  Education Pctl               7932 non-null   float64
#  47  Linguistic Isolation         7715 non-null   float64
#  48  Linguistic Isolation Pctl    7715 non-null   float64
#  49  Poverty                      7960 non-null   float64
#  50  Poverty Pctl                 7960 non-null   float64
#  51  Unemployment                 7700 non-null   float64
#  52  Unemployment Pctl            7700 non-null   float64
#  53  Housing Burden               7890 non-null   float64
#  54  Housing Burden Pctl          7890 non-null   float64
#  55  Pop. Char.                   7932 non-null   float64
#  56  Pop. Char. Score             7932 non-null   float64
#  57  Pop. Char. Pctl              7932 non-null   float64
# dtypes: float64(51), int64(3), object(4)
# memory usage: 3.6+ MB

# %%
columns_to_keep = ['Census Tract',
                   'Total Population',
                   'California County',
                   'Approximate Location',
                   'CES 4.0 Score',
                   'CES 4.0 Percentile',
                   'CES 4.0 Percentile Range',
                   'PM2.5 Pctl',
                   'Groundwater Threats Pctl',
                   'Asthma Pctl',
                   'Low Birth Weight Pctl',
                   'Unemployment Pctl',
                   'Housing Burden Pctl',
                   'Pollution Burden Pctl',
                   'Drinking Water Pctl',
                   'Tox. Release Pctl',
                   'Cleanup Sites Pctl',
                   'Poverty Pctl',
                   'Housing Burden Pctl',
                   'Cardiovascular Disease Pctl']
df2 = df[columns_to_keep]
df2.info
# Out:
# <bound method DataFrame.info of      Census Tract  Total Population California County  \
# 0     06019001100              2780           Fresno
# 1     06077000700              4680       San Joaquin
# 2     06037204920              2751       Los Angeles
# 3     06019000700              3664           Fresno
# 4     06019000200              2689           Fresno
# ...           ...               ...               ...
# 8030  06107004000               582           Tulare
# 8031  06109985202              2509         Tuolumne
# 8032  06111001206               778          Ventura
# 8033  06111003012               675          Ventura
# 8034  06111980000               118          Ventura
#
#                      Approximate Location  CES 4.0 Score  CES 4.0 Percentile  \
# 0                                  Fresno          93.18              100.00
# 1                                Stockton          86.65               99.99
# 2                             Los Angeles          82.39               99.97
# 3                                  Fresno          81.33               99.96
# 4                                  Fresno          80.75               99.95
# ...                                   ...            ...                 ...
# 8030                          Porterville            NaN                 NaN
# 8031  Unincorporated Tuolumne County area            NaN                 NaN
# 8032   Unincorporated Ventura County area            NaN                 NaN
# 8033                               Oxnard            NaN                 NaN
# 8034   Unincorporated Ventura County area            NaN                 NaN
#
#       CES 4.0 Percentile Range  PM2.5 Pctl  Groundwater Threats Pctl  \
# 0     95-100% (highest scores)       97.71                     91.17
# 1     95-100% (highest scores)       72.59                     95.09
# 2     95-100% (highest scores)       89.21                     68.92
# 3     95-100% (highest scores)       95.88                     44.83
# 4     95-100% (highest scores)       97.47                     78.05
# ...                        ...         ...                       ...
# 8030                       NaN       94.49                      0.00
# 8031                       NaN       40.96                     22.12
# 8032                       NaN       16.74                     66.96
# 8033                       NaN       36.94                      2.11
# 8034                       NaN        2.87                      0.00
#
#       Asthma Pctl  Low Birth Weight Pctl  Unemployment Pctl  \
# 0           97.22                  95.62              93.83
# 1           94.22                  88.72              99.21
# 2           82.76                  90.89              61.53
# 3           98.24                  99.78              97.35
# 4           98.17                  99.67              95.29
# ...           ...                    ...                ...
# 8030        71.09                    NaN                NaN
# 8031        77.57                    NaN                NaN
# 8032        54.06                    NaN                NaN
# 8033        49.25                    NaN                NaN
# 8034        71.88                    NaN                NaN
#
#       Housing Burden Pctl  Pollution Burden Pctl  Drinking Water Pctl  \
# 0                   91.04                  99.93                84.39
# 1                   92.28                  99.29                41.55
# 2                   63.97                  99.86                92.53
# 3                   96.41                  97.40                84.39
# 4                   94.16                  96.94                84.39
# ...                   ...                    ...                  ...
# 8030                  NaN                  49.58                71.15
# 8031                  NaN                  10.90                42.73
# 8032                78.47                  79.27                44.81
# 8033                  NaN                  54.11                72.92
# 8034                  NaN                   0.02                 0.59
#
#       Tox. Release Pctl  Cleanup Sites Pctl  Poverty Pctl  \
# 0                 92.20               98.19         98.92
# 1                 52.35               97.46         98.39
# 2                 87.73               92.96         93.39
# 3                 74.93               77.32         95.35
# 4                 78.96               62.45         98.30
# ...                 ...                 ...           ...
# 8030               8.23                0.00         99.42
# 8031              19.45                0.00           NaN
# 8032              14.32               71.91         27.35
# 8033              45.91                2.07        100.00
# 8034               0.00               41.40           NaN
#
#       Housing Burden Pctl  Cardiovascular Disease Pctl
# 0                   91.04                        92.25
# 1                   92.28                        88.12
# 2                   63.97                        90.15
# 3                   96.41                        94.57
# 4                   94.16                        94.43
# ...                   ...                          ...
# 8030                  NaN                        91.55
# 8031                  NaN                        95.01
# 8032                78.47                        19.20
# 8033                  NaN                        48.22
# 8034                  NaN                        67.70
#
# [8035 rows x 20 columns]>

# %% [markdown]
# Next, I narrow this information to the county of Los Angeles.

# %%
df2LA = df2[df2['California County'] == 'Los Angeles']

# %% [markdown]
# And rename the Census Tracts to a FIPS variable in order to allow for analysis using one word later on. I use the info command after renaming to confirm that the data successfully narrowed from California as a whole and that the column name was successfully changed.

# %%
df2LA.rename(columns = {'Census Tract':'FIPS'}, inplace = True)
# Out:
# /tmp/ipykernel_3178/1790350419.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2LA.rename(columns = {'Census Tract':'FIPS'}, inplace = True)

# %%
df2LA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2343 entries, 2 to 7990
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   FIPS                         2343 non-null   object
#  1   Total Population             2343 non-null   int64
#  2   California County            2343 non-null   object
#  3   Approximate Location         2343 non-null   object
#  4   CES 4.0 Score                2297 non-null   float64
#  5   CES 4.0 Percentile           2297 non-null   float64
#  6   CES 4.0 Percentile Range     2297 non-null   object
#  7   PM2.5 Pctl                   2343 non-null   float64
#  8   Groundwater Threats Pctl     2343 non-null   float64
#  9   Asthma Pctl                  2334 non-null   float64
#  10  Low Birth Weight Pctl        2279 non-null   float64
#  11  Unemployment Pctl            2263 non-null   float64
#  12  Housing Burden Pctl          2283 non-null   float64
#  13  Pollution Burden Pctl        2343 non-null   float64
#  14  Drinking Water Pctl          2326 non-null   float64
#  15  Tox. Release Pctl            2343 non-null   float64
#  16  Cleanup Sites Pctl           2343 non-null   float64
#  17  Poverty Pctl                 2305 non-null   float64
#  18  Housing Burden Pctl          2283 non-null   float64
#  19  Cardiovascular Disease Pctl  2334 non-null   float64
# dtypes: float64(15), int64(1), object(4)
# memory usage: 384.4+ KB

# %% [markdown]
# Next, I want to merge this information with geometry data, in this case based on census tracts, because it is the measure used in CalEnviroscreen.

# %%
tracts = gpd.read_file('Data/2020_Census_Tracts.geojson')
tracts.head()
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed
#    OBJECTID    CT20    LABEL   ShapeSTArea  ShapeSTLength  \
# 0      4992  101110  1011.10  1.229562e+07   15083.854287
# 1      4993  101122  1011.22  2.845774e+07   31671.455844
# 2      4994  101220  1012.20  7.522093e+06   12698.783810
# 3      4995  101221  1012.21  3.812000e+06    9161.710543
# 4      4996  101222  1012.22  3.191371e+06    9980.600461
#
#                                             geometry
# 0  POLYGON ((-118.29793 34.26323, -118.30082 34.2...
# 1  POLYGON ((-118.27743 34.25991, -118.27743 34.2...
# 2  POLYGON ((-118.27818 34.25577, -118.27887 34.2...
# 3  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  POLYGON ((-118.28594 34.25590, -118.28697 34.2...

# %%
tracts['FIPS'] ='06' + '037' + tracts['CT20']

# %%
CEStracts=tracts.merge(df2LA,on='FIPS')

# %% [markdown]
# After this, I also confirm that the projection of the geodataframe is mercator in order to allow us to join our calenviroscreen information with information about oil wells in the county.

# %%
CEStracts.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# # Oil Wells Data

# %% [markdown]
# Now, I am adding the oil wells data to the mix.

# %%
dfoil = pd.read_csv('Data/Oil_Wells.csv')

# %% [markdown]
# I create a variable for active oil wells as well in case we add oil wells to any maps later in this file.

# %%
df_act = dfoil.drop(dfoil[dfoil['WellStatus'] != 'A'].index)

# %%
gdf_act = gpd.GeoDataFrame(df_act, 
                       crs='epsg:4326',
                       geometry=gpd.points_from_xy(df_act.Longitude, df_act.Latitude))

# %% [markdown]
# And now I join the oil data with CalEnviroscreen.

# %%
# Perform a spatial join based on geographic coordinates
gdfoilCES = gpd.sjoin(gdf_act, CEStracts, how='right', op='within')
gdfoilCES.head()
# Out:
# /opt/conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3493: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#    index_left   X   Y  OBJECTID_left DistrictNu  APINumber BLMWell DryHole  \
# 0         NaN NaN NaN            NaN        NaN        NaN     NaN     NaN
# 1         NaN NaN NaN            NaN        NaN        NaN     NaN     NaN
# 2         NaN NaN NaN            NaN        NaN        NaN     NaN     NaN
# 3         NaN NaN NaN            NaN        NaN        NaN     NaN     NaN
# 4         NaN NaN NaN            NaN        NaN        NaN     NaN     NaN
#
#   WellStatus OperatorNa  ... Low Birth Weight Pctl Unemployment Pctl  \
# 0        NaN        NaN  ...                 13.91             69.98
# 1        NaN        NaN  ...                 32.47             49.86
# 2        NaN        NaN  ...                 36.14             86.75
# 3        NaN        NaN  ...                 17.68             35.02
# 4        NaN        NaN  ...                 60.06             58.36
#
#    Housing Burden Pctl  Pollution Burden Pctl Drinking Water Pctl  \
# 0                93.89                  29.07               83.13
# 1                37.48                  19.50               77.57
# 2                95.25                  36.65               83.13
# 3                56.86                  55.73               83.13
# 4                53.12                  61.32               75.32
#
#   Tox. Release Pctl Cleanup Sites Pctl  Poverty Pctl  Housing Burden Pctl  \
# 0             59.51                0.0         57.79                93.89
# 1             59.19                0.0         17.49                37.48
# 2             60.07                0.0         72.84                95.25
# 3             61.00                0.0         27.05                56.86
# 4             61.39                0.0         48.73                53.12
#
#   Cardiovascular Disease Pctl
# 0                       75.46
# 1                       55.53
# 2                       75.46
# 3                       45.13
# 4                       38.66
#
# [5 rows x 53 columns]

# %% [markdown]
# And I use the info command to look at the data.

# %%
gdfoilCES.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 4664 entries, 0 to 2017
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   index_left                   2750 non-null   float64
#  1   X                            2750 non-null   float64
#  2   Y                            2750 non-null   float64
#  3   OBJECTID_left                2750 non-null   float64
#  4   DistrictNu                   2750 non-null   object
#  5   APINumber                    2750 non-null   float64
#  6   BLMWell                      2750 non-null   object
#  7   DryHole                      2750 non-null   object
#  8   WellStatus                   2750 non-null   object
#  9   OperatorNa                   2750 non-null   object
#  10  CountyName                   2750 non-null   object
#  11  FieldName                    2750 non-null   object
#  12  AreaName                     2750 non-null   object
#  13  Section                      2750 non-null   float64
#  14  Township                     2750 non-null   object
#  15  Range                        2750 non-null   object
#  16  BaseMeridi                   2750 non-null   object
#  17  Latitude                     2750 non-null   float64
#  18  Longitude                    2750 non-null   float64
#  19  GISSourceC                   2750 non-null   object
#  20  LeaseName                    2750 non-null   object
#  21  Directiona                   2750 non-null   object
#  22  GISSymbol                    2750 non-null   object
#  23  LatestUpdate                 2750 non-null   object
#  24  DataSource                   2750 non-null   object
#  25  TOOLTIP                      2750 non-null   object
#  26  NLA_URL                      2750 non-null   object
#  27  OBJECTID_right               4664 non-null   int64
#  28  CT20                         4664 non-null   object
#  29  LABEL                        4664 non-null   object
#  30  ShapeSTArea                  4664 non-null   float64
#  31  ShapeSTLength                4664 non-null   float64
#  32  geometry                     4664 non-null   geometry
#  33  FIPS                         4664 non-null   object
#  34  Total Population             4664 non-null   int64
#  35  California County            4664 non-null   object
#  36  Approximate Location         4664 non-null   object
#  37  CES 4.0 Score                4086 non-null   float64
#  38  CES 4.0 Percentile           4086 non-null   float64
#  39  CES 4.0 Percentile Range     4086 non-null   object
#  40  PM2.5 Pctl                   4664 non-null   float64
#  41  Groundwater Threats Pctl     4664 non-null   float64
#  42  Asthma Pctl                  4609 non-null   float64
#  43  Low Birth Weight Pctl        4070 non-null   float64
#  44  Unemployment Pctl            4039 non-null   float64
#  45  Housing Burden Pctl          4077 non-null   float64
#  46  Pollution Burden Pctl        4664 non-null   float64
#  47  Drinking Water Pctl          4422 non-null   float64
#  48  Tox. Release Pctl            4664 non-null   float64
#  49  Cleanup Sites Pctl           4664 non-null   float64
#  50  Poverty Pctl                 4088 non-null   float64
#  51  Housing Burden Pctl          4077 non-null   float64
#  52  Cardiovascular Disease Pctl  4609 non-null   float64
# dtypes: float64(25), geometry(1), int64(2), object(25)
# memory usage: 1.9+ MB

# %% [markdown]
# # How CES related to oil wells

# %%
oilwellsbytract = gdfoilCES.FIPS.value_counts().rename_axis('FIPS').reset_index(name='oilwell_count')

# %%
oilwellsbytract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2018 entries, 0 to 2017
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FIPS           2018 non-null   object
#  1   oilwell_count  2018 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 31.7+ KB

# %%
# join the summary table back to the gdf
gdfoilCES=gdfoilCES.merge(oilwellsbytract,on='FIPS')

# %% [markdown]
# It doesn't make sense to adjust for population like we did in the lab as this feature of oil well count does not need to be adjusted by the number of people. So, next step is just to confirm that the merge worked, which it did.

# %%
gdfoilCES.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 4664 entries, 0 to 4663
# Data columns (total 54 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   index_left                   2750 non-null   float64
#  1   X                            2750 non-null   float64
#  2   Y                            2750 non-null   float64
#  3   OBJECTID_left                2750 non-null   float64
#  4   DistrictNu                   2750 non-null   object
#  5   APINumber                    2750 non-null   float64
#  6   BLMWell                      2750 non-null   object
#  7   DryHole                      2750 non-null   object
#  8   WellStatus                   2750 non-null   object
#  9   OperatorNa                   2750 non-null   object
#  10  CountyName                   2750 non-null   object
#  11  FieldName                    2750 non-null   object
#  12  AreaName                     2750 non-null   object
#  13  Section                      2750 non-null   float64
#  14  Township                     2750 non-null   object
#  15  Range                        2750 non-null   object
#  16  BaseMeridi                   2750 non-null   object
#  17  Latitude                     2750 non-null   float64
#  18  Longitude                    2750 non-null   float64
#  19  GISSourceC                   2750 non-null   object
#  20  LeaseName                    2750 non-null   object
#  21  Directiona                   2750 non-null   object
#  22  GISSymbol                    2750 non-null   object
#  23  LatestUpdate                 2750 non-null   object
#  24  DataSource                   2750 non-null   object
#  25  TOOLTIP                      2750 non-null   object
#  26  NLA_URL                      2750 non-null   object
#  27  OBJECTID_right               4664 non-null   int64
#  28  CT20                         4664 non-null   object
#  29  LABEL                        4664 non-null   object
#  30  ShapeSTArea                  4664 non-null   float64
#  31  ShapeSTLength                4664 non-null   float64
#  32  geometry                     4664 non-null   geometry
#  33  FIPS                         4664 non-null   object
#  34  Total Population             4664 non-null   int64
#  35  California County            4664 non-null   object
#  36  Approximate Location         4664 non-null   object
#  37  CES 4.0 Score                4086 non-null   float64
#  38  CES 4.0 Percentile           4086 non-null   float64
#  39  CES 4.0 Percentile Range     4086 non-null   object
#  40  PM2.5 Pctl                   4664 non-null   float64
#  41  Groundwater Threats Pctl     4664 non-null   float64
#  42  Asthma Pctl                  4609 non-null   float64
#  43  Low Birth Weight Pctl        4070 non-null   float64
#  44  Unemployment Pctl            4039 non-null   float64
#  45  Housing Burden Pctl          4077 non-null   float64
#  46  Pollution Burden Pctl        4664 non-null   float64
#  47  Drinking Water Pctl          4422 non-null   float64
#  48  Tox. Release Pctl            4664 non-null   float64
#  49  Cleanup Sites Pctl           4664 non-null   float64
#  50  Poverty Pctl                 4088 non-null   float64
#  51  Housing Burden Pctl          4077 non-null   float64
#  52  Cardiovascular Disease Pctl  4609 non-null   float64
#  53  oilwell_count                4664 non-null   int64
# dtypes: float64(25), geometry(1), int64(3), object(25)
# memory usage: 1.9+ MB

# %%
columnsfull = ['ShapeSTArea',
               'ShapeSTLength',
               'geometry',
                    'FIPS',
                  'Total Population',
                   'California County',
                   'Approximate Location',
                   'CES 4.0 Score',
                   'CES 4.0 Percentile',
                   'CES 4.0 Percentile Range',
                   'PM2.5 Pctl',
                   'Groundwater Threats Pctl',
                   'Asthma Pctl',
                   'Low Birth Weight Pctl',
                   'Unemployment Pctl',
                   'Housing Burden Pctl',
                   'Pollution Burden Pctl',
                   'Drinking Water Pctl',
                   'Tox. Release Pctl',
                   'Cleanup Sites Pctl',
                   'Poverty Pctl',
                   'Housing Burden Pctl',
                   'Cardiovascular Disease Pctl',
                    'oilwell_count']
gdfoilCES = gdfoilCES[columnsfull]
gdfoilCES.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 4664 entries, 0 to 4663
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ShapeSTArea                  4664 non-null   float64
#  1   ShapeSTLength                4664 non-null   float64
#  2   geometry                     4664 non-null   geometry
#  3   FIPS                         4664 non-null   object
#  4   Total Population             4664 non-null   int64
#  5   California County            4664 non-null   object
#  6   Approximate Location         4664 non-null   object
#  7   CES 4.0 Score                4086 non-null   float64
#  8   CES 4.0 Percentile           4086 non-null   float64
#  9   CES 4.0 Percentile Range     4086 non-null   object
#  10  PM2.5 Pctl                   4664 non-null   float64
#  11  Groundwater Threats Pctl     4664 non-null   float64
#  12  Asthma Pctl                  4609 non-null   float64
#  13  Low Birth Weight Pctl        4070 non-null   float64
#  14  Unemployment Pctl            4039 non-null   float64
#  15  Housing Burden Pctl          4077 non-null   float64
#  16  Housing Burden Pctl          4077 non-null   float64
#  17  Pollution Burden Pctl        4664 non-null   float64
#  18  Drinking Water Pctl          4422 non-null   float64
#  19  Tox. Release Pctl            4664 non-null   float64
#  20  Cleanup Sites Pctl           4664 non-null   float64
#  21  Poverty Pctl                 4088 non-null   float64
#  22  Housing Burden Pctl          4077 non-null   float64
#  23  Housing Burden Pctl          4077 non-null   float64
#  24  Cardiovascular Disease Pctl  4609 non-null   float64
#  25  oilwell_count                4664 non-null   int64
# dtypes: float64(19), geometry(1), int64(2), object(4)
# memory usage: 947.5+ KB

# %% [markdown]
# Now, I made a scatterplot to see if we see a relationship for CES and oil well counts.

# %%
import seaborn as sns
ax = sns.scatterplot(x="oilwell_count", y="CES 4.0 Score", data=gdfoilCES)
ax.set_title("Oil Wells and CalEnviroscreen")
ax.set_xlabel("Oil well per census tract");

# %% [markdown]
# This showcases the challenge that many categories do not have any oil wells (or more accurately are marked as 1 oil well within the dataset.) So in order to look if there is a relationship here, I want to better isolate areas with a large concentration of oil wells.

# %%
#here I create a variable of top 10% of census tracts by the amount of oil wells.  
topoilwells = gdfoilCES.sort_values(by='oilwell_count', axis=0, ascending=False, na_position='last').head(466)

# %% [markdown]
# Now I run a head and tails analysis to confirm that worked and get a sense of the amount of oil wells in both categories.

# %%
topoilwells.head()
# Out:
#        ShapeSTArea  ShapeSTLength  \
# 4528  3.082185e+08   77789.700597
# 4459  3.082185e+08   77789.700597
# 4461  3.082185e+08   77789.700597
# 4462  3.082185e+08   77789.700597
# 4463  3.082185e+08   77789.700597
#
#                                                geometry         FIPS  \
# 4528  POLYGON ((-118.20551 33.78265, -118.20631 33.7...  06037980033
# 4459  POLYGON ((-118.20551 33.78265, -118.20631 33.7...  06037980033
# 4461  POLYGON ((-118.20551 33.78265, -118.20631 33.7...  06037980033
# 4462  POLYGON ((-118.20551 33.78265, -118.20631 33.7...  06037980033
# 4463  POLYGON ((-118.20551 33.78265, -118.20631 33.7...  06037980033
#
#       Total Population California County Approximate Location  CES 4.0 Score  \
# 4528                16       Los Angeles           Long Beach            NaN
# 4459                16       Los Angeles           Long Beach            NaN
# 4461                16       Los Angeles           Long Beach            NaN
# 4462                16       Los Angeles           Long Beach            NaN
# 4463                16       Los Angeles           Long Beach            NaN
#
#       CES 4.0 Percentile CES 4.0 Percentile Range  ...  Housing Burden Pctl  \
# 4528                 NaN                      NaN  ...                  NaN
# 4459                 NaN                      NaN  ...                  NaN
# 4461                 NaN                      NaN  ...                  NaN
# 4462                 NaN                      NaN  ...                  NaN
# 4463                 NaN                      NaN  ...                  NaN
#
#       Pollution Burden Pctl  Drinking Water Pctl  Tox. Release Pctl  \
# 4528                  98.43                34.73              96.46
# 4459                  98.43                34.73              96.46
# 4461                  98.43                34.73              96.46
# 4462                  98.43                34.73              96.46
# 4463                  98.43                34.73              96.46
#
#       Cleanup Sites Pctl  Poverty Pctl  Housing Burden Pctl  \
# 4528               97.72           NaN                  NaN
# 4459               97.72           NaN                  NaN
# 4461               97.72           NaN                  NaN
# 4462               97.72           NaN                  NaN
# 4463               97.72           NaN                  NaN
#
#       Housing Burden Pctl  Cardiovascular Disease Pctl  oilwell_count
# 4528                  NaN                        19.52            278
# 4459                  NaN                        19.52            278
# 4461                  NaN                        19.52            278
# 4462                  NaN                        19.52            278
# 4463                  NaN                        19.52            278
#
# [5 rows x 26 columns]

# %%
topoilwells.tail()
# Out:
#        ShapeSTArea  ShapeSTLength  \
# 1318  1.888165e+07   19842.785052
# 1319  1.888165e+07   19842.785052
# 1314  1.888165e+07   19842.785052
# 1321  1.888165e+07   19842.785052
# 1323  1.888165e+07   19842.785052
#
#                                                geometry         FIPS  \
# 1318  POLYGON ((-118.24328 33.78473, -118.24353 33.7...  06037294701
# 1319  POLYGON ((-118.24328 33.78473, -118.24353 33.7...  06037294701
# 1314  POLYGON ((-118.24328 33.78473, -118.24353 33.7...  06037294701
# 1321  POLYGON ((-118.24328 33.78473, -118.24353 33.7...  06037294701
# 1323  POLYGON ((-118.24328 33.78473, -118.24353 33.7...  06037294701
#
#       Total Population California County Approximate Location  CES 4.0 Score  \
# 1318              3099       Los Angeles          Los Angeles          71.29
# 1319              3099       Los Angeles          Los Angeles          71.29
# 1314              3099       Los Angeles          Los Angeles          71.29
# 1321              3099       Los Angeles          Los Angeles          71.29
# 1323              3099       Los Angeles          Los Angeles          71.29
#
#       CES 4.0 Percentile  CES 4.0 Percentile Range  ...  Housing Burden Pctl  \
# 1318               99.27  95-100% (highest scores)  ...                91.46
# 1319               99.27  95-100% (highest scores)  ...                91.46
# 1314               99.27  95-100% (highest scores)  ...                91.46
# 1321               99.27  95-100% (highest scores)  ...                91.46
# 1323               99.27  95-100% (highest scores)  ...                91.46
#
#       Pollution Burden Pctl  Drinking Water Pctl  Tox. Release Pctl  \
# 1318                  97.98                42.43              97.24
# 1319                  97.98                42.43              97.24
# 1314                  97.98                42.43              97.24
# 1321                  97.98                42.43              97.24
# 1323                  97.98                42.43              97.24
#
#       Cleanup Sites Pctl  Poverty Pctl  Housing Burden Pctl  \
# 1318               95.24         90.87                91.46
# 1319               95.24         90.87                91.46
# 1314               95.24         90.87                91.46
# 1321               95.24         90.87                91.46
# 1323               95.24         90.87                91.46
#
#       Housing Burden Pctl  Cardiovascular Disease Pctl  oilwell_count
# 1318                91.46                        92.82            194
# 1319                91.46                        92.82            194
# 1314                91.46                        92.82            194
# 1321                91.46                        92.82            194
# 1323                91.46                        92.82            194
#
# [5 rows x 26 columns]

# %% [markdown]
# Next, I wanted to create a variable for the census tracts with either a very small or no oil wells. As the generic dataset seems to have 1 as the lowest number, I am using 5 as the threshold.

# %%
oilwellsyn = (gdfoilCES['oilwell_count'] < 5)
nooilwells = gdfoilCES[oilwellsyn]

# %%
nooilwells.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 1993 entries, 0 to 4663
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ShapeSTArea                  1993 non-null   float64
#  1   ShapeSTLength                1993 non-null   float64
#  2   geometry                     1993 non-null   geometry
#  3   FIPS                         1993 non-null   object
#  4   Total Population             1993 non-null   int64
#  5   California County            1993 non-null   object
#  6   Approximate Location         1993 non-null   object
#  7   CES 4.0 Score                1967 non-null   float64
#  8   CES 4.0 Percentile           1967 non-null   float64
#  9   CES 4.0 Percentile Range     1967 non-null   object
#  10  PM2.5 Pctl                   1993 non-null   float64
#  11  Groundwater Threats Pctl     1993 non-null   float64
#  12  Asthma Pctl                  1987 non-null   float64
#  13  Low Birth Weight Pctl        1956 non-null   float64
#  14  Unemployment Pctl            1940 non-null   float64
#  15  Housing Burden Pctl          1965 non-null   float64
#  16  Housing Burden Pctl          1965 non-null   float64
#  17  Pollution Burden Pctl        1993 non-null   float64
#  18  Drinking Water Pctl          1980 non-null   float64
#  19  Tox. Release Pctl            1993 non-null   float64
#  20  Cleanup Sites Pctl           1993 non-null   float64
#  21  Poverty Pctl                 1969 non-null   float64
#  22  Housing Burden Pctl          1965 non-null   float64
#  23  Housing Burden Pctl          1965 non-null   float64
#  24  Cardiovascular Disease Pctl  1987 non-null   float64
#  25  oilwell_count                1993 non-null   int64
# dtypes: float64(19), geometry(1), int64(2), object(4)
# memory usage: 420.4+ KB

# %% [markdown]
# Next, I wanted to create a variable for the majority of census tracts, not those with such a small amount they may not have oil wells at all.

# %%
anyoilwells = gdfoilCES.drop(gdfoilCES[oilwellsyn].index)

# %%
anyoilwells.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 2671 entries, 44 to 4659
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ShapeSTArea                  2671 non-null   float64
#  1   ShapeSTLength                2671 non-null   float64
#  2   geometry                     2671 non-null   geometry
#  3   FIPS                         2671 non-null   object
#  4   Total Population             2671 non-null   int64
#  5   California County            2671 non-null   object
#  6   Approximate Location         2671 non-null   object
#  7   CES 4.0 Score                2119 non-null   float64
#  8   CES 4.0 Percentile           2119 non-null   float64
#  9   CES 4.0 Percentile Range     2119 non-null   object
#  10  PM2.5 Pctl                   2671 non-null   float64
#  11  Groundwater Threats Pctl     2671 non-null   float64
#  12  Asthma Pctl                  2622 non-null   float64
#  13  Low Birth Weight Pctl        2114 non-null   float64
#  14  Unemployment Pctl            2099 non-null   float64
#  15  Housing Burden Pctl          2112 non-null   float64
#  16  Housing Burden Pctl          2112 non-null   float64
#  17  Pollution Burden Pctl        2671 non-null   float64
#  18  Drinking Water Pctl          2442 non-null   float64
#  19  Tox. Release Pctl            2671 non-null   float64
#  20  Cleanup Sites Pctl           2671 non-null   float64
#  21  Poverty Pctl                 2119 non-null   float64
#  22  Housing Burden Pctl          2112 non-null   float64
#  23  Housing Burden Pctl          2112 non-null   float64
#  24  Cardiovascular Disease Pctl  2622 non-null   float64
#  25  oilwell_count                2671 non-null   int64
# dtypes: float64(19), geometry(1), int64(2), object(4)
# memory usage: 563.4+ KB

# %% [markdown]
# I created a scatterplot of the relationship between oil wells and CES for after removing census tracts without oil wells, and we do see a positive correlation.

# %%
sns.lmplot(x="oilwell_count", y="CES 4.0 Percentile", data=anyoilwells);

# %% [markdown]
# Next, I import map tools to look at this data more closely.

# %% [markdown]
# I am really interested in looking at a correlation coefficient for this information so below I used scipy documentation to look at oil wells and CES. Because there are some nan figures, I had trouble with the correlation both using spatial autocorrelation and pearsons coefficient. I fuond a solution in using numpy to compare finite scores.

# %%
import numpy as np
from scipy import stats

oilwell_count_a = anyoilwells['oilwell_count']
CES_score_a = anyoilwells['CES 4.0 Percentile']

valid_indices = np.isfinite(oilwell_count_a) & np.isfinite(CES_score_a)

# Calculate Pearson correlation coefficient and p-value
correlation_coefficient, p_value = stats.pearsonr(oilwell_count_a[valid_indices], CES_score_a[valid_indices])

print(f"Pearson correlation coefficient: {correlation_coefficient}")
print(f"P-value: {p_value}")
# Out:
# Pearson correlation coefficient: 0.3434112086571628
# P-value: 1.0375727862080937e-59

# %% [markdown]
# We can interpret the pearson correlation as a moderate positive correlation between the count of oil wells and cal enviroscreen with a p score of less than 0.001.

# %% [markdown]
# Next, I create versions of CES score across the variables I created above for graphing.

# %%
CES_score_t = topoilwells['CES 4.0 Percentile']
CES_score_n = nooilwells['CES 4.0 Percentile']
CES_score = gdfoilCES['CES 4.0 Percentile']

# %%
import matplotlib.pyplot as plt

# First comparing CES scores across all of the categories created
means = [CES_score_a.mean(), CES_score_t.mean(), CES_score_n.mean(), CES_score.mean()]
categories = ['CES_score_a', 'CES_score_t', 'CES_score_n', 'CES_score']

# Plotting the bar chart
plt.bar(categories, means, color='blue')
plt.ylabel('Mean CES Score')
plt.title('Mean CES Score for Different Groups')
plt.show()

# %% [markdown]
# As these were not tremendously different, I created another version using just the top CES scores compared to the data at large.

# %%
means = [CES_score_t.mean(), CES_score.mean()]
categories = ['Top 10% Oil Wells', 'All Census Tracts']

# Plotting the bar chart
plt.bar(categories, means, color='black')
plt.ylabel('Mean CES Score Percentile')
plt.title('Cal Enviroscreen and oil across census tracts')
plt.savefig('CESoil.png')
plt.show()

# %% [markdown]
# Next, I wanted to see how the components of CalEnviroscreen might vary between these two groups.

# %%
# Select the columns of interest
CES_columns_detail = ['Groundwater Threats Pctl','PM2.5 Pctl','Asthma Pctl','Low Birth Weight Pctl','Unemployment Pctl','Housing Burden Pctl']

# Calculate means for both DataFrames
means_topoilwells = topoilwells[CES_columns_detail].mean()
means_gdfstats = gdfoilCES[CES_columns_detail].mean()

# Combine means into a new DataFrame for plotting
combined_means = pd.concat([means_topoilwells, means_gdfstats], axis=1)
combined_means.columns = ['Top 10% oil wells', 'All census tracts']

# Plotting the grouped bar chart
combined_means.plot(kind='bar', color=['black', 'grey'])
plt.ylabel('Group mean percentile')
plt.xlabel('Categories of CalEnviroscreen')
plt.title('Areas with the most oil wells by CalEnviroscreen measures')
plt.savefig('CESmeans.png')
plt.show()

# %% [markdown]
# This graphic provides more clarity on the high calenviroscreen rating in high oil well locations. Some of these factors seem likely included in Calenviroscreen measures, like cleanup sites and groundwater threats. Health impacts are only slightly higher, potentially insignificant, but there are differences in population characteristics, in line with the analyses we found looking at race and income, also reflected here in poverty and housing burden.
